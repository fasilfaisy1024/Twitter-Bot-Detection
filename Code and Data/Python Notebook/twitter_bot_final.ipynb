# %%
# %cd "/content/drive/MyDrive/main-project"
# Out:
# /content/drive/MyDrive/main-project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filepath = '/content/drive/MyDrive/dataset/'
file= filepath+'training_data_2_csv_UTF.csv'

training_data = pd.read_csv(file)
bots = training_data[training_data.bot==1]
nonbots = training_data[training_data.bot==0]

# %%
training_data
# Out:
#                 id                id_str       screen_name  \
# 0     8.160000e+17  "815745789754417152"  "HoustonPokeMap"
# 1     4.843621e+09            4843621225         kernyeahx
# 2     4.303727e+09            4303727112   mattlieberisbot
# 3     3.063139e+09            3063139353         sc_papers
# 4     2.955142e+09            2955142070      lucarivera16
# ...            ...                   ...               ...
# 2792  2.362091e+08             236209129     leslieberland
# 2793  2.545039e+08             254503881      SamuelsPants
# 2794  1.548544e+07              15485441       jimmyfallon
# 2795  7.513869e+08             751386872    LocalAlligator
# 2796  1.992936e+07              19929362      RepJoeBarton
#
#                        location  \
# 0                 "Houston, TX"
# 1     Templeville town, MD, USA
# 2                           NaN
# 3                           NaN
# 4         Dublin, United States
# ...                         ...
# 2792                        NaN
# 2793                brooklyn NY
# 2794         New York, New York
# 2795    England, United Kingdom
# 2796                  Ennis, TX
#
#                                             description  \
# 0     "Rare and strong PokŽmon in Houston, TX. See m...
# 1     From late 2014 Socium Marketplace will make sh...
# 2     Inspired by the smart, funny folks at @replyal...
# 3                                                   NaN
# 4                Inspiring cooks everywhere since 1956.
# ...                                                 ...
# 2792  Twitter CMO. Favorite title: Mama. Never, ever...
# 2793  I live in brooklyn, I'm a bike messenger, I pl...
# 2794                                     astrophysicist
# 2795  I'm quite out of my mind, actually, but people...
# 2796  I work for the people of the 6th District of T...
#
#                             url  followers_count  friends_count  listed_count  \
# 0     "https://t.co/dnWuDbFRkt"             1291              0            10
# 1                           NaN                1            349             0
# 2       https://t.co/P1e1o0m4KC             1086              0            14
# 3                           NaN               33              0             8
# 4                           NaN               11            745             0
# ...                         ...              ...            ...           ...
# 2792                        NaN            18998           2005           425
# 2793     http://t.co/CQkADdjfaw               32             54             0
# 2794     http://t.co/fgp5RYqr3T         45044433           7451         68157
# 2795                        NaN               16             64             1
# 2796     http://t.co/UcrfIiWGdl            22490            308          1342
#
#                             created_at  favourites_count  verified  \
# 0     "Mon Jan 02 02:25:26 +0000 2017"                 0     False
# 1                        2/1/2016 7:37                38     False
# 2       Fri Nov 20 18:53:22 +0000 2015                 0     False
# 3                      2/25/2015 20:11                 0     False
# 4                       1/1/2015 17:44               146     False
# ...                                ...               ...       ...
# 2792                    1/10/2011 2:06              2503     False
# 2793    Sat Feb 19 12:12:42 +0000 2011                 1     False
# 2794                   7/18/2008 19:46                24      True
# 2795                   8/11/2012 14:53                15     False
# 2796    Mon Feb 02 20:30:20 +0000 2009                43      True
#
#       statuses_count  lang                                             status  \
# 0              78554  "en"  {\r      "created_at": "Sun Mar 12 15:44:04 +0...
# 1                 31    en                                                NaN
# 2                713    en  {'retweeted': False, 'is_quote_status': False,...
# 3                676    en  Construction of human anti-tetanus single-chai...
# 4                185    en                                                NaN
# ...              ...   ...                                                ...
# 2792            3498    en  RT @StationCDRKelly: Dreaming of napping in sp...
# 2793              97    en  {'geo': None, 'in_reply_to_status_id': None, '...
# 2794            9606    en  Status(contributors=None, truncated=False, tex...
# 2795              62    en  {'created_at': 'Sun Feb 26 15:51:57 +0000 2017...
# 2796            1897    en  {u'contributors': None, u'truncated': False, u...
#
#       default_profile  default_profile_image has_extended_profile  \
# 0                True                  False                False
# 1                True                  False                False
# 2                True                  False                False
# 3                True                   True                False
# 4               False                  False                False
# ...               ...                    ...                  ...
# 2792            False                  False                 True
# 2793             True                  False                False
# 2794            False                  False                False
# 2795            False                  False                 True
# 2796             True                  False                 True
#
#                       name  bot
# 0     "Houston PokŽ Alert"    1
# 1              Keri Nelson    1
# 2       Matt Lieber Is Bot    1
# 3       single cell papers    1
# 4             lucarivera16    1
# ...                    ...  ...
# 2792        Leslie Berland    0
# 2793    Samuel Littlefield    0
# 2794          jimmy fallon    0
# 2795        Tammas Foxdene    0
# 2796            Joe Barton    0
#
# [2797 rows x 20 columns]

# %%
bag_of_words_bot = r'bot|prison|paper|follow me|tweet me|swag|bang|b0t|magic|face|wizard|bot|b0t|cannabis|tweet me|mishear|follow me|updates every|gorilla|yes_ofc|forget' \
                    r'expos|kill|clit|bbb|butt|fuck|XXX|sex|truthe|fake|anony|free|virus|funky|RNA|kuck|jargon' \
                    r'nerd|swag|jack|bang|bonsai|chick|prison|paper|pokem|xx|freak|ffd|dunia|clone|genie|bbb' \
                    r'ffd|onlyman|emoji|joke|troll|droop|free|every|wow|cheese|yeah|bio|magic|wizard|face'
            
training_data['screen_name_binary'] = training_data.screen_name.str.contains(bag_of_words_bot, case=False, na=False)
training_data['name_binary'] = training_data.name.str.contains(bag_of_words_bot, case=False, na=False)
training_data['description_binary'] = training_data.description.str.contains(bag_of_words_bot, case=False, na=False)
training_data['status_binary'] = training_data.status.str.contains(bag_of_words_bot, case=False, na=False)

# %%
training_data.columns
# Out:
# Index(['id', 'id_str', 'screen_name', 'location', 'description', 'url',
#        'followers_count', 'friends_count', 'listed_count', 'created_at',
#        'favourites_count', 'verified', 'statuses_count', 'lang', 'status',
#        'default_profile', 'default_profile_image', 'has_extended_profile',
#        'name', 'bot', 'screen_name_binary', 'name_binary',
#        'description_binary', 'status_binary'],
#       dtype='object')

# %%
training_data
# Out:
#                 id                id_str       screen_name  \
# 0     8.160000e+17  "815745789754417152"  "HoustonPokeMap"
# 1     4.843621e+09            4843621225         kernyeahx
# 2     4.303727e+09            4303727112   mattlieberisbot
# 3     3.063139e+09            3063139353         sc_papers
# 4     2.955142e+09            2955142070      lucarivera16
# ...            ...                   ...               ...
# 2792  2.362091e+08             236209129     leslieberland
# 2793  2.545039e+08             254503881      SamuelsPants
# 2794  1.548544e+07              15485441       jimmyfallon
# 2795  7.513869e+08             751386872    LocalAlligator
# 2796  1.992936e+07              19929362      RepJoeBarton
#
#                        location  \
# 0                 "Houston, TX"
# 1     Templeville town, MD, USA
# 2                           NaN
# 3                           NaN
# 4         Dublin, United States
# ...                         ...
# 2792                        NaN
# 2793                brooklyn NY
# 2794         New York, New York
# 2795    England, United Kingdom
# 2796                  Ennis, TX
#
#                                             description  \
# 0     "Rare and strong PokŽmon in Houston, TX. See m...
# 1     From late 2014 Socium Marketplace will make sh...
# 2     Inspired by the smart, funny folks at @replyal...
# 3                                                   NaN
# 4                Inspiring cooks everywhere since 1956.
# ...                                                 ...
# 2792  Twitter CMO. Favorite title: Mama. Never, ever...
# 2793  I live in brooklyn, I'm a bike messenger, I pl...
# 2794                                     astrophysicist
# 2795  I'm quite out of my mind, actually, but people...
# 2796  I work for the people of the 6th District of T...
#
#                             url  followers_count  friends_count  listed_count  \
# 0     "https://t.co/dnWuDbFRkt"             1291              0            10
# 1                           NaN                1            349             0
# 2       https://t.co/P1e1o0m4KC             1086              0            14
# 3                           NaN               33              0             8
# 4                           NaN               11            745             0
# ...                         ...              ...            ...           ...
# 2792                        NaN            18998           2005           425
# 2793     http://t.co/CQkADdjfaw               32             54             0
# 2794     http://t.co/fgp5RYqr3T         45044433           7451         68157
# 2795                        NaN               16             64             1
# 2796     http://t.co/UcrfIiWGdl            22490            308          1342
#
#                             created_at  ...  \
# 0     "Mon Jan 02 02:25:26 +0000 2017"  ...
# 1                        2/1/2016 7:37  ...
# 2       Fri Nov 20 18:53:22 +0000 2015  ...
# 3                      2/25/2015 20:11  ...
# 4                       1/1/2015 17:44  ...
# ...                                ...  ...
# 2792                    1/10/2011 2:06  ...
# 2793    Sat Feb 19 12:12:42 +0000 2011  ...
# 2794                   7/18/2008 19:46  ...
# 2795                   8/11/2012 14:53  ...
# 2796    Mon Feb 02 20:30:20 +0000 2009  ...
#
#                                                  status  default_profile  \
# 0     {\r      "created_at": "Sun Mar 12 15:44:04 +0...             True
# 1                                                   NaN             True
# 2     {'retweeted': False, 'is_quote_status': False,...             True
# 3     Construction of human anti-tetanus single-chai...             True
# 4                                                   NaN            False
# ...                                                 ...              ...
# 2792  RT @StationCDRKelly: Dreaming of napping in sp...            False
# 2793  {'geo': None, 'in_reply_to_status_id': None, '...             True
# 2794  Status(contributors=None, truncated=False, tex...            False
# 2795  {'created_at': 'Sun Feb 26 15:51:57 +0000 2017...            False
# 2796  {u'contributors': None, u'truncated': False, u...             True
#
#       default_profile_image has_extended_profile                  name  bot  \
# 0                     False                False  "Houston PokŽ Alert"    1
# 1                     False                False           Keri Nelson    1
# 2                     False                False    Matt Lieber Is Bot    1
# 3                      True                False    single cell papers    1
# 4                     False                False          lucarivera16    1
# ...                     ...                  ...                   ...  ...
# 2792                  False                 True        Leslie Berland    0
# 2793                  False                False    Samuel Littlefield    0
# 2794                  False                False          jimmy fallon    0
# 2795                  False                 True        Tammas Foxdene    0
# 2796                  False                 True            Joe Barton    0
#
#       screen_name_binary name_binary description_binary  status_binary
# 0                   True       False              False           True
# 1                   True       False              False          False
# 2                   True        True               True           True
# 3                   True        True              False          False
# 4                  False       False               True          False
# ...                  ...         ...                ...            ...
# 2792               False       False              False          False
# 2793               False       False               True          False
# 2794               False       False              False          False
# 2795               False       False              False          False
# 2796               False       False              False          False
#
# [2797 rows x 24 columns]

# %%
training_data['listed_count_binary'] = (training_data.listed_count>20000)==False
features = ['screen_name_binary', 'name_binary',
       'description_binary', 'status_binary','verified','followers_count','friends_count','statuses_count','listed_count_binary','bot']

# %%
print(len(features))
# Out:
# 10

# %%
training_data[features]
# Out:
#       screen_name_binary  name_binary  description_binary  status_binary  \
# 0                   True        False               False           True
# 1                   True        False               False          False
# 2                   True         True                True           True
# 3                   True         True               False          False
# 4                  False        False                True          False
# ...                  ...          ...                 ...            ...
# 2792               False        False               False          False
# 2793               False        False                True          False
# 2794               False        False               False          False
# 2795               False        False               False          False
# 2796               False        False               False          False
#
#       verified  followers_count  friends_count  statuses_count  \
# 0        False             1291              0           78554
# 1        False                1            349              31
# 2        False             1086              0             713
# 3        False               33              0             676
# 4        False               11            745             185
# ...        ...              ...            ...             ...
# 2792     False            18998           2005            3498
# 2793     False               32             54              97
# 2794      True         45044433           7451            9606
# 2795     False               16             64              62
# 2796      True            22490            308            1897
#
#       listed_count_binary  bot
# 0                    True    1
# 1                    True    1
# 2                    True    1
# 3                    True    1
# 4                    True    1
# ...                   ...  ...
# 2792                 True    0
# 2793                 True    0
# 2794                False    0
# 2795                 True    0
# 2796                 True    0
#
# [2797 rows x 10 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn import metrics

X = training_data[features].iloc[:,:-1]
y = training_data[features].iloc[:,-1]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
 print("class 0 : {}".format(sum(y_train == 0)))
print("class 1 : {}".format(sum(y_train == 1)))

from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)

X_train_res, y_train_res = sm.fit_resample(X_train, y_train)
# Out:
# class 0 : 1053
# class 1 : 904

# %%
print("class 0 : {}".format(sum(y_train_res == 0)))
print("class 1 : {}".format(sum(y_train_res == 1)))
# Out:
# class 0 : 1053
# class 1 : 1053

# %%
import numpy as np
from collections import Counter

class Node:
    def __init__(self, feature=None, threshold=None, left=None, right=None,*,value=None):
        self.feature = feature
        self.threshold = threshold
        self.left = left
        self.right = right
        self.value = value
        
    def is_leaf_node(self):
        return self.value is not None


class DecisionTree:
    def __init__(self, min_samples_split=2, max_depth=150, n_features=None):
        self.min_samples_split=min_samples_split
        self.max_depth=max_depth
        self.n_features=n_features
        self.root=None

    def fit(self, X, y):
        self.n_features = X.shape[1] if not self.n_features else min(X.shape[1],self.n_features)
        self.root = self._grow_tree(X, y)

    def _grow_tree(self, X, y, depth=0):
        n_samples, n_feats = X.shape
        n_labels = len(np.unique(y))

        # check the stopping criteria
        if (depth>=self.max_depth or n_labels==1 or n_samples<self.min_samples_split):
            leaf_value = self._most_common_label(y)
            return Node(value=leaf_value)

        feat_idxs = np.random.choice(n_feats, self.n_features, replace=False)

        # find the best split
        best_feature, best_thresh = self._best_split(X, y, feat_idxs)

        # create child nodes
        left_idxs, right_idxs = self._split(X[:, best_feature], best_thresh)
        left = self._grow_tree(X[left_idxs, :], y[left_idxs], depth+1)
        right = self._grow_tree(X[right_idxs, :], y[right_idxs], depth+1)
        return Node(best_feature, best_thresh, left, right)


    def _best_split(self, X, y, feat_idxs):
        best_gain = -1
        split_idx, split_threshold = None, None

        for feat_idx in feat_idxs:
            X_column = X[:, feat_idx]
            thresholds = np.unique(X_column)

            for thr in thresholds:
                # calculate the information gain
                gain = self._information_gain(y, X_column, thr)

                if gain > best_gain:
                    best_gain = gain
                    split_idx = feat_idx
                    split_threshold = thr

        return split_idx, split_threshold


    def _information_gain(self, y, X_column, threshold):
        # parent entropy
        parent_entropy = self._entropy(y)

        # create children
        left_idxs, right_idxs = self._split(X_column, threshold)

        if len(left_idxs) == 0 or len(right_idxs) == 0:
            return 0
        
        # calculate the weighted avg. entropy of children
        n = len(y)
        n_l, n_r = len(left_idxs), len(right_idxs)
        e_l, e_r = self._entropy(y[left_idxs]), self._entropy(y[right_idxs])
        child_entropy = (n_l/n) * e_l + (n_r/n) * e_r

        # calculate the IG
        information_gain = parent_entropy - child_entropy
        return information_gain

    def _split(self, X_column, split_thresh):
        left_idxs = np.argwhere(X_column <= split_thresh).flatten()
        right_idxs = np.argwhere(X_column > split_thresh).flatten()
        return left_idxs, right_idxs

    def _entropy(self, y):
        hist = np.bincount(y)
        ps = hist / len(y)
        return -np.sum([p * np.log(p) for p in ps if p>0])


    def _most_common_label(self, y):
        counter = Counter(y)
        value = counter.most_common(1)[0][0]
        return value
    

    def predict(self, X):
        return np.array([self._traverse_tree(x, self.root) for x in X])

    def _traverse_tree(self, x, node):
        if node.is_leaf_node():
            return node.value

        if x[node.feature] <= node.threshold:
            return self._traverse_tree(x, node.left)
        return self._traverse_tree(x, node.right)

# %%
import numpy as np
from collections import Counter

class RandomForest:
    def __init__(self, n_trees=3, max_depth=10, min_samples_split=2, n_feature=None):
        self.n_trees = n_trees
        self.max_depth=max_depth
        self.min_samples_split=min_samples_split
        self.n_features=n_feature
        self.trees = []

    def fit(self, X, y):
        self.trees = []
        for _ in range(self.n_trees):
            tree = DecisionTree(max_depth=self.max_depth,
                            min_samples_split=self.min_samples_split,
                            n_features=self.n_features)
            X_sample, y_sample = self._bootstrap_samples(X, y)
            tree.fit(X_sample, y_sample)
            self.trees.append(tree)

    def _bootstrap_samples(self, X, y):
        n_samples = X.shape[0]
        idxs = np.random.choice(n_samples, n_samples, replace=True)
        return X[idxs], y[idxs]

    def _most_common_label(self, y):
        counter = Counter(y)
        most_common = counter.most_common(1)[0][0]
        return most_common


    def predict(self, X):
        predictions = np.array([tree.predict(X) for tree in self.trees])
        tree_preds = np.swapaxes(predictions, 0, 1)
        predictions = np.array([self._most_common_label(pred) for pred in tree_preds])
        return predictions

# %%
clf = RandomForest(n_trees=3)
clf.fit(X_train_res.values, y_train_res.values)

# %%
y_pred_train = clf.predict(X_train_res.values)
y_pred_test = clf.predict(X_test.values)

print("Trainig Accuracy: %.5f" %accuracy_score(y_train_res, y_pred_train))
print("Test Accuracy: %.5f" %accuracy_score(y_test, y_pred_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-fd7c37a89eb2> in <cell line: 4>()
#       2 y_pred_test = clf.predict(X_test.values)
#       3
# ----> 4 print("Trainig Accuracy: %.5f" %accuracy_score(y_train_res, y_pred_train))
#       5 print("Test Accuracy: %.5f" %accuracy_score(y_test, y_pred_test))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     190
#     191             try:
# --> 192                 return func(*args, **kwargs)
#     193             except InvalidParameterError as e:
#     194                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     219
#     220     # Compute accuracy for each possible representation
# --> 221     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     222     check_consistent_length(y_true, y_pred, sample_weight)
#     223     if y_type.startswith("multilabel"):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      93
#      94     if len(y_type) > 1:
# ---> 95         raise ValueError(
#      96             "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      97                 type_true, type_pred
#
# ValueError: Classification metrics can't handle a mix of binary and continuous-multioutput targets

# %%
print(classification_report(y_test, y_pred_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-161-1f029a0a811f> in <cell line: 1>()
# ----> 1 print(classification_report(y_test, y_pred_test))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2308     """
#    2309
# -> 2310     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2311
#    2312     if labels is None:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      93
#      94     if len(y_type) > 1:
# ---> 95         raise ValueError(
#      96             "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      97                 type_true, type_pred
#
# ValueError: Classification metrics can't handle a mix of binary and continuous-multioutput targets

# %%
cm2 = confusion_matrix(y_test, y_pred_test)

cm_display2 = metrics.ConfusionMatrixDisplay(confusion_matrix = cm2, display_labels = ["non-bot","bot"])

cm_display2.plot()
plt.show()

# %%
import pickle 
pickle.dump(clf, open('model.pkl', 'wb'))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score


# Predict probabilities of the positive class
y_scores = clf.predict_proba(X_test)[:, 1]

# Calculate the false positive rate (FPR), true positive rate (TPR), and threshold
fpr, tpr, thresholds = roc_curve(y_test, y_scores)

# Calculate the Area Under the Curve (AUC)
auc = roc_auc_score(y_test, y_scores)

# Plotting the ROC curve
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line for random classifier
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-0b0597fdb132> in <cell line: 9>()
#       7
#       8 # Predict probabilities of the positive class
# ----> 9 y_scores = clf.predict_proba(X_test)[:, 1]
#      10
#      11 # Calculate the false positive rate (FPR), true positive rate (TPR), and threshold
#
# <ipython-input-125-d929d37efcef> in predict_proba(self, X)
#      66
#      67     def predict_proba(self, X):
# ---> 68         predictions = np.array([tree.predict(X) for tree in self.trees])
#      69         tree_probs = np.swapaxes(predictions, 0, 1)
#      70         class_probs = []
#
# <ipython-input-125-d929d37efcef> in <listcomp>(.0)
#      66
#      67     def predict_proba(self, X):
# ---> 68         predictions = np.array([tree.predict(X) for tree in self.trees])
#      69         tree_probs = np.swapaxes(predictions, 0, 1)
#      70         class_probs = []
#
# <ipython-input-124-0eadd6b74699> in predict(self, X)
#     119
#     120     def predict(self, X):
# --> 121         return np.array([self._traverse_tree(x, self.root) for x in X])
#     122
#     123     def _traverse_tree(self, x, node):
#
# <ipython-input-124-0eadd6b74699> in <listcomp>(.0)
#     119
#     120     def predict(self, X):
# --> 121         return np.array([self._traverse_tree(x, self.root) for x in X])
#     122
#     123     def _traverse_tree(self, x, node):
#
# <ipython-input-124-0eadd6b74699> in _traverse_tree(self, x, node)
#     125             return node.value
#     126
# --> 127         if x[node.feature] <= node.threshold:
#     128             return self._traverse_tree(x, node.left)
#     129         return self._traverse_tree(x, node.right)
#
# TypeError: '<=' not supported between instances of 'str' and 'bool'

# %% [markdown]
# # Test

# %%
df = pd.read_csv("test - Sheet1.csv")

# %%
df
# Out:
#        screen_name  followers_count  friends_count  listed_count  verified  \
# 0        kernyeahx                1            349             0     False
# 1       FUNKO_BOTS             2522             51             6     False
# 2          ValdakR                4              0             0     False
# 3      akshaykumar         16933838             21         14682      True
# 4  FuckReverendHax              157             82             1     False
# 5       EmmaWatson         24370134            353         45931      True
# 6      FCBarcelona         20709433             59         28967      True
# 7       Harveytown         19740200           1510         47944      True
# 8     hima_jin_bot               57             34             6     False
# 9       wizkhalifa         29145797            800         27906      True
#
#                                          description  statuses_count  \
# 0  From late 2014 Socium Marketplace will make sh...              31
# 1  3D NFT Bots created by Funko\r\n8888 Retro Sty...             108
# 2  You love it harshly? Come in! 💛💛💛 http://qo2ur...              22
# 3                                               None            3673
# 4  tweets that EXPOSE the TRUTH about the deceive...           40438
# 5  Actor & @UN_Women Global Goodwill Ambassador. ...            1573
# 6  More official accounts @fcbarcelona_cat @fcbar...           85887
# 7  New album, A Head Full Of Dreams, out now worl...            6454
# 8  ã‚ˆã†ã€ãã•ã‚Œæš‡äººã©ã‚‚ã€‚\n 4å‰²æ‰‹å‹•...           78995
# 9                                        Taylor Gang           42988
#
#                 name                                             status
# 0        Keri Nelson                                               null
# 1   FUNKO’Z BOT LIFE                                               None
# 2         Sandy Pass                                               None
# 3       Akshay Kumar  {u'lang': u'en', u'truncated': True, u'text': ...
# 4  TRUTHerbot EXPOSE  {'created_at': 'Tue Feb 14 12:23:01 +0000 2017...
# 5        Emma Watson  {u'lang': u'en', u'truncated': True, u'text': ...
# 6       FC Barcelona  {u'lang': u'en', u'text': u'[RIVAL WATCH] Juve...
# 7           Coldplay  {u'lang': u'en', u'text': u'Everglowing in Tha...
# 8          æš‡äººbot  {u'lang': u'ja', u'text': u'\u3044\u3064\u307e...
# 9        Wiz Khalifa  {u'lang': u'en', u'text': u'Bout to go live on...

# %%
df['listed_count_binary'] = (df.listed_count>20000)==False

# %%
bag_of_words_bot = r'bot|prison|paper|follow me|tweet me|swag|bang|b0t|magic|face|wizard|bot|b0t|cannabis|tweet me|mishear|follow me|updates every|gorilla|yes_ofc|forget' \
                    r'expos|kill|clit|bbb|butt|fuck|XXX|sex|truthe|fake|anony|free|virus|funky|RNA|kuck|jargon' \
                    r'nerd|swag|jack|bang|bonsai|chick|prison|paper|pokem|xx|freak|ffd|dunia|clone|genie|bbb' \
                    r'ffd|onlyman|emoji|joke|troll|droop|free|every|wow|cheese|yeah|bio|magic|wizard|face'

df['screen_name_binary'] = df.screen_name.str.contains(bag_of_words_bot, case=False, na=False)
df['name_binary'] = df.name.str.contains(bag_of_words_bot, case=False, na=False)
df['description_binary'] = df.description.str.contains(bag_of_words_bot, case=False, na=False)
df['status_binary'] = df.status.str.contains(bag_of_words_bot, case=False, na=False)

# %%
features = ['screen_name_binary', 'name_binary',
       'description_binary', 'status_binary','verified','followers_count','friends_count','statuses_count','listed_count_binary']

# %%
df[features]
# Out:
#    screen_name_binary  name_binary  description_binary  status_binary  \
# 0                True        False               False          False
# 1                True         True                True          False
# 2               False        False               False          False
# 3               False        False               False          False
# 4                True         True               False           True
# 5               False        False                True          False
# 6               False        False               False          False
# 7               False        False               False           True
# 8                True         True               False           True
# 9               False        False               False           True
#
#    verified  followers_count  friends_count  statuses_count  \
# 0     False                1            349              31
# 1     False             2522             51             108
# 2     False                4              0              22
# 3      True         16933838             21            3673
# 4     False              157             82           40438
# 5      True         24370134            353            1573
# 6      True         20709433             59           85887
# 7      True         19740200           1510            6454
# 8     False               57             34           78995
# 9      True         29145797            800           42988
#
#    listed_count_binary
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True
# 5                False
# 6                False
# 7                False
# 8                 True
# 9                False

# %%
predn = clf.predict(df[features].values)

for x in predn:
  if x==1:
    print("Bot")
  else:
    print("Human")
# Out:
# Bot
# Bot
# Bot
# Human
# Bot
# Human
# Human
# Human
# Bot
# Human
